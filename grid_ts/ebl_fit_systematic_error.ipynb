# %%
from fermipy.gtanalysis import GTAnalysis
from ts_limit.grid_ts.janitor import Janitor
import numpy as np

# %%
# !ls ../roi_simulation/roi_files/fits_01
# Out:
# bexpmap_00.fits				 fit_newminuit.fits
# bexpmap_roi_00.fits			 fit_newminuit.npy
# ccube_00.fits				 ft1_00.fits
# ccube.fits				 gtbin.par
# config_local.yaml			 gtdrm.par
# config_modified.yaml			 gtexpcube2.par
# config.yaml				 gtmktime.par
# drm_2.fits				 gtselect.par
# drm_6.fits				 gtsrcmaps.par
# evfile_00.txt				 ltcube_00.fits
# fermipy.log				 post_opt_00.xml
# fit_minuit_00.xml			 post_opt.fits
# fit_minuit_4fgl_j0319.8+4130_sed.fits	 post_opt.npy
# fit_minuit_4fgl_j0319.8+4130_sedlnl.png  setup_00.xml
# fit_minuit_4fgl_j0319.8+4130_sed.npy	 setup.fits
# fit_minuit_4fgl_j0319.8+4130_sed.png	 setup.npy
# fit_minuit.fits				 srcmap_00.fits
# fit_minuit.npy				 srcmdl_00.xml
# fit_newminuit_00.xml

# %%
! cat ../roi_simulation/roi_files/fits_01/config_modified.yaml
# Out:
# binning:
#   binsperdec: 30
#   binsz: 0.2
#   roiwidth: 10.0
# data:
#   evfile: events.lst
#   ltcube: /nfs/astrop/n1/kuhlmann/NGC_1275/ts_limit/roi_simulation/roi_files/fits_01/ltcube_00.fits
#   scfile: /nfs/astrop/n1/kuhlmann/NGC_1275/raw_data_roi_15/L2009090432059398E3A906_SC00.fits
# fileio:
#   logfile: /nfs/astrop/n1/kuhlmann/NGC_1275/ts_limit/roi_simulation/roi_files/fits_01/fermipy.log
#   outdir: /nfs/astrop/n1/kuhlmann/NGC_1275/ts_limit/roi_simulation/roi_files/fits_01
#   workdir: /nfs/astrop/n1/kuhlmann/NGC_1275/ts_limit/roi_simulation/roi_files/fits_01
# gtlike:
#   edisp: true
#   edisp_bins: -6
#   edisp_disable:
#   - isodiff
#   irfs: P8R3_SOURCE_V3
# logging:
#   verbosity: 4
# model:
#   catalogs:
#   - gll_psc_v21.xml
#   galdiff: /nfs/astrop/n1/kuhlmann/miniconda/envs/fermi3/share/fermitools/refdata/fermi/galdiffuse/gll_iem_v07.fits
#   isodiff: /nfs/astrop/n1/kuhlmann/miniconda/envs/fermi3/share/fermitools/refdata/fermi/galdiffuse/iso_P8R3_SOURCE_V3_v1.txt
# ...

# %%
! cat ../grid_survival_prob/ebl_attenuation.dat
# Out:
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# 1.000000000000000000e+00
# ...

# %%
gta = GTAnalysis.create('../roi_simulation/roi_files/fits_01/fit_newminuit.npy', config='../roi_simulation/roi_files/fits_01/config_modified.yaml')
# Out:
# /nfs/astrop/n1/kuhlmann/miniconda/envs/fermi3/lib/python3.7/site-packages/fermipy/config.py:213: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config_dict = yaml.load(open(config))
# 2021-09-01 10:53:14 INFO    GTAnalysis.__init__():
# --------------------------------------------------------------------------------
# fermipy version v1.0.0
# ScienceTools version 2.0.0
# 2021-09-01 10:53:14 DEBUG   GTAnalysis.print_config(): Configuration:
# binning:
#   binsperdec: 30.0
#   binsz: 0.2
#   coordsys: CEL
#   enumbins: null
#   hpx_ebin: true
#   hpx_order: 10
#   hpx_ordering_scheme: RING
#   npix: null
#   proj: AIT
#   projtype: WCS
#   roiwidth: 10.0
# components: []
# data:
#   cacheft1: true
#   evfile: events.lst
#   ltcube: /nfs/astrop/n1/kuhlmann/NGC_1275/ts_limit/roi_simulation/roi_files/fits_01/ltcube_00.fits
# ...

# %%
gta.like()
# Out:
# -421747.67656475457

# %%
j = Janitor(gta)
# Out:
# 2021-09-01 10:58:37 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J0319.8+4130     : ['norm', 'alpha', 'beta']
# 2021-09-01 10:58:37 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J0316.8+4120     : ['Prefactor']
# 2021-09-01 10:58:37 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J0315.5+4231     : ['Prefactor']
# 2021-09-01 10:58:37 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J0312.9+4119     : ['Prefactor']
# 2021-09-01 10:58:37 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J0333.8+4007     : ['Prefactor']
# 2021-09-01 10:58:37 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J0310.9+3815     : ['Prefactor']
# 2021-09-01 10:58:37 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J0340.3+4130     : ['Prefactor']
# 2021-09-01 10:58:38 INFO    GTAnalysis.free_source(): Fixing parameters for isodiff               : ['Normalization']
# ...

# %%
j.gta.like()
# Out:
# -421747.6765651853

# %%
j.prob = np.loadtxt('../grid_survival_prob/ebl_attenuation.dat')

# %%
j.p = j.prob

# %%
j.p.shape
# Out:
# (183,)

# %%
j.fit()
# Out:
# 2021-09-01 11:00:02 DEBUG   GTAnalysis.get_src_model(): Generating source dict for 4FGL J0319.8+4130
# 2021-09-01 11:00:02 DEBUG   GTAnalysis.profile_norm(): Profiling 4FGL J0319.8+4130
# 2021-09-01 11:00:03 DEBUG   GTAnalysis.profile_norm(): Finished
# 2021-09-01 11:00:03 DEBUG   GTAnalysis.get_src_model(): Generating source dict for 4FGL J0319.8+4130
# 2021-09-01 11:00:03 DEBUG   GTAnalysis.profile_norm(): Profiling 4FGL J0319.8+4130
# 2021-09-01 11:00:03 DEBUG   GTAnalysis.profile_norm(): Finished
# 2021-09-01 11:00:03 DEBUG   GTAnalysis.get_src_model(): Generating source dict for 4FGL J0319.8+4130
# 2021-09-01 11:00:03 DEBUG   GTAnalysis.profile_norm(): Profiling 4FGL J0319.8+4130
# 2021-09-01 11:00:04 DEBUG   GTAnalysis.profile_norm(): Finished
# 2021-09-01 11:00:04 DEBUG   GTAnalysis.get_src_model(): Generating source dict for 4FGL J0319.8+4130
# 2021-09-01 11:00:04 DEBUG   GTAnalysis.profile_norm(): Profiling 4FGL J0319.8+4130
# ...

# %%
j.gta.like()
# Out:
# -421747.86106041295
